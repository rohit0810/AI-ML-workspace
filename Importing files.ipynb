# %% [markdown]
# # Working with CSV files

# %% [markdown]
# ## Opening local csv file

# %%
import pandas as pd
df1=pd.read_csv("E:\excel\cars.csv")

# %%
df1.head()
# Out:
#    YEAR        Make           Model        Size  (kW) Unnamed: 5 TYPE  \
# 0  2012  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 1  2012      NISSAN            LEAF    MID-SIZE    80         A1    B
# 2  2013        FORD  FOCUS ELECTRIC     COMPACT   107         A1    B
# 3  2013  MITSUBISHI          i-MiEV  SUBCOMPACT    49         A1    B
# 4  2013      NISSAN            LEAF    MID-SIZE    80         A1    B
#
#    CITY (kWh/100 km)  HWY (kWh/100 km)  COMB (kWh/100 km)  CITY (Le/100 km)  \
# 0               16.9              21.4               18.7               1.9
# 1               19.3              23.0               21.1               2.2
# 2               19.0              21.1               20.0               2.1
# 3               16.9              21.4               18.7               1.9
# 4               19.3              23.0               21.1               2.2
#
#    HWY (Le/100 km)  COMB (Le/100 km)  (g/km)  RATING  (km)  TIME (h)
# ...

# %% [markdown]
# ## Opening a csv file from an URL

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/cs109/2014_data/master/countries.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers=headers)
data = StringIO(req.text)

pd.read_csv(data)
# Out:
#        Country         Region
# 0      Algeria         AFRICA
# 1       Angola         AFRICA
# 2        Benin         AFRICA
# 3     Botswana         AFRICA
# 4      Burkina         AFRICA
# ..         ...            ...
# 189   Paraguay  SOUTH AMERICA
# 190       Peru  SOUTH AMERICA
# 191   Suriname  SOUTH AMERICA
# 192    Uruguay  SOUTH AMERICA
# 193  Venezuela  SOUTH AMERICA
#
# [194 rows x 2 columns]

# %%
df2=pd.read_csv("E:\excel\movie_titles_metadata.tsv",sep='\t') #when table seperated values were given
df2.head()
# Out:
#        m0  10 things i hate about you  1999  6.90     62847  \
# 0      m1  1492: conquest of paradise  1992   6.2   10421.0
# 1      m2                  15 minutes  2001   6.1   25854.0
# 2      m3       2001: a space odyssey  1968   8.4  163227.0
# 3      m4                     48 hrs.  1982   6.9   22289.0
# 4      m5           the fifth element  1997   7.5  133756.0
# ..    ...                         ...   ...   ...       ...
# 611  m612                    watchmen  2009   7.8  135229.0
# 612  m613                         xxx  2002   5.6   53505.0
# 613  m614                       x-men  2000   7.4  122149.0
# 614  m615          young frankenstein  1974   8.0   57618.0
# 615  m616                   zulu dawn  1979   6.4    1911.0
#
#                                   ['comedy' 'romance']
# 0          ['adventure' 'biography' 'drama' 'history']
# 1                ['action' 'crime' 'drama' 'thriller']
# 2                     ['adventure' 'mystery' 'sci-fi']
# ...

# %%
df3=pd.read_csv("E:\excel\movie_titles_metadata.tsv",sep='\t', names=['a','b','c','d','e','f']) 
df3.head()
# Out:
#         a                           b     c    d         e  \
# 0      m0  10 things i hate about you  1999  6.9   62847.0
# 1      m1  1492: conquest of paradise  1992  6.2   10421.0
# 2      m2                  15 minutes  2001  6.1   25854.0
# 3      m3       2001: a space odyssey  1968  8.4  163227.0
# 4      m4                     48 hrs.  1982  6.9   22289.0
# ..    ...                         ...   ...  ...       ...
# 612  m612                    watchmen  2009  7.8  135229.0
# 613  m613                         xxx  2002  5.6   53505.0
# 614  m614                       x-men  2000  7.4  122149.0
# 615  m615          young frankenstein  1974  8.0   57618.0
# 616  m616                   zulu dawn  1979  6.4    1911.0
#
#                                                      f
# 0                                 ['comedy' 'romance']
# 1          ['adventure' 'biography' 'drama' 'history']
# 2                ['action' 'crime' 'drama' 'thriller']
# ...

# %% [markdown]
# # Working with JSON File

# %% [markdown]
# ## Loading local json file

# %%
import pandas as pd

# %%
df4=pd.read_json("E:/excel/train.json")

# %%
df4
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %% [markdown]
# ## Reading from URL

# %%
df5=pd.read_json("http://ergast.com/api/f1/2004/1/results.json")
df5
# Out:
#                                                       MRData
# RaceTable  {'season': '2004', 'round': '1', 'Races': [{'s...
# limit                                                     30
# offset                                                     0
# series                                                    f1
# total                                                     20
# url             http://ergast.com/api/f1/2004/1/results.json
# xmlns                              http://ergast.com/mrd/1.5

# %% [markdown]
# # Working with SQL

# %%
#!pip install mysql.connector
# Out:
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      --------------------------------------- 0.0/11.9 MB 330.3 kB/s eta 0:00:36
#      --------------------------------------- 0.0/11.9 MB 326.8 kB/s eta 0:00:37
#       --------------------------------------- 0.2/11.9 MB 1.1 MB/s eta 0:00:12
#      - -------------------------------------- 0.5/11.9 MB 2.2 MB/s eta 0:00:06
#      -- ------------------------------------- 0.8/11.9 MB 2.9 MB/s eta 0:00:04
#      --- ------------------------------------ 1.0/11.9 MB 3.3 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.2/11.9 MB 3.3 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.4/11.9 MB 3.5 MB/s eta 0:00:03
#      ----- ---------------------------------- 1.6/11.9 MB 3.6 MB/s eta 0:00:03
# ...

# %%
import mysql.connector

# %%
conn=mysql.connector.connect(host='localhost',user='root',password='',database='world')

# %%
df6=pd.read_sql_query("SELECT * FROM city",conn)
# Out:
# C:\Users\Rohit Kharat\AppData\Local\Temp\ipykernel_13472\1615048669.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df6=pd.read_sql_query("SELECT * FROM city",conn)

# %%
df6
# Out:
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# 4076  4077        Jabaliya         PSE     North Gaza      113901
# 4077  4078          Nablus         PSE         Nablus      100231
# 4078  4079           Rafah         PSE          Rafah       92020
#
# [4079 rows x 5 columns]

# %% [markdown]
# ## Fetching an API and converting JSON to Dataframe

# %%
#rapidAPI
import requests

url = "https://covid-19-statistics.p.rapidapi.com/regions"

headers = {
    "X-RapidAPI-Key": "9bd884bb8fmsh140839af79edb59p10686fjsncd6241804173",
    "X-RapidAPI-Host": "covid-19-statistics.p.rapidapi.com"
}

response1 = requests.get(url, headers=headers)

print(response1.json())
# Out:
# {'data': [{'iso': 'CHN', 'name': 'China'}, {'iso': 'TWN', 'name': 'Taipei and environs'}, {'iso': 'USA', 'name': 'US'}, {'iso': 'JPN', 'name': 'Japan'}, {'iso': 'THA', 'name': 'Thailand'}, {'iso': 'KOR', 'name': 'Korea, South'}, {'iso': 'SGP', 'name': 'Singapore'}, {'iso': 'PHL', 'name': 'Philippines'}, {'iso': 'MYS', 'name': 'Malaysia'}, {'iso': 'VNM', 'name': 'Vietnam'}, {'iso': 'AUS', 'name': 'Australia'}, {'iso': 'MEX', 'name': 'Mexico'}, {'iso': 'BRA', 'name': 'Brazil'}, {'iso': 'COL', 'name': 'Colombia'}, {'iso': 'FRA', 'name': 'France'}, {'iso': 'NPL', 'name': 'Nepal'}, {'iso': 'CAN', 'name': 'Canada'}, {'iso': 'KHM', 'name': 'Cambodia'}, {'iso': 'LKA', 'name': 'Sri Lanka'}, {'iso': 'CIV', 'name': "Cote d'Ivoire"}, {'iso': 'DEU', 'name': 'Germany'}, {'iso': 'FIN', 'name': 'Finland'}, {'iso': 'ARE', 'name': 'United Arab Emirates'}, {'iso': 'IND', 'name': 'India'}, {'iso': 'ITA', 'name': 'Italy'}, {'iso': 'GBR', 'name': 'United Kingdom'}, {'iso': 'RUS', 'name': 'Russia'}, {'iso'
# ...

# %%
df6=pd.DataFrame(response1.json()['data'])

# %%
df6
# Out:
#      iso                 name
# 0    CHN                China
# 1    TWN  Taipei and environs
# 2    USA                   US
# 3    JPN                Japan
# 4    THA             Thailand
# ..   ...                  ...
# 214  KIR             Kiribati
# 215  PLW                Palau
# 216  TON                Tonga
# 217  NRU                Nauru
# 218  TUV               Tuvalu
#
# [219 rows x 2 columns]

# %%
df6.to_csv('country_code.csv', index=False)

# %% [markdown]
# ## Web Scraping

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}
webpage=requests.get('https://www.ambitionbox.com/list-of-companies?page=1',headers=headers).text

# %%
soup=BeautifulSoup(webpage,'lxml')

# %%
#print(soup.prettify())

# %%
soup.find_all('h1')[0].text
# Out:
# '\n\t\t\t\t\t\t\tList of companies in India\n\t\t\t\t\t\t'

# %%
company=soup.find_all('div',class_='companyCardWrapper__primaryInformation')

# %%
len(company)
# Out:
# 20

# %%
#company

# %%
name=[]
rating=[]
reviews=[]

for i in company:
    name.append(i.find('h2').text.strip())
    rating.append(i.find('span',class_='companyCardWrapper__companyRatingValue').text.strip())

# %%
name
# Out:
# ['TCS',
#  'Accenture',
#  'Cognizant',
#  'Wipro',
#  'HDFC Bank',
#  'ICICI Bank',
#  'Infosys',
#  'Capgemini',
#  'HCLTech',
#  'Tech Mahindra',
#  'Genpact',
#  'Axis Bank',
#  'Concentrix Corporation',
#  'Teleperformance',
#  'Amazon',
#  'Reliance Jio',
#  'IBM',
#  'Larsen & Toubro Limited',
#  'Reliance Retail',
#  'HDB Financial Services']

# %%
campany2=soup.find_all('div',class_='companyCardWrapper__tertiaryInformation')

# %%
for i in campany2:
    #name.append(i.find('h2').text.strip())
    #rating.append(i.find('span',class_='companyCardWrapper__companyRatingValue').text.strip())
    reviews.append(i.find('span',class_='companyCardWrapper__ActionCount').text.strip())

# %%
reviews
# Out:
# ['71.9k',
#  '45.5k',
#  '41k',
#  '36.4k',
#  '33.3k',
#  '33k',
#  '31.2k',
#  '29.1k',
#  '27.9k',
#  '27.1k',
#  '25.7k',
#  '21.7k',
#  '21.4k',
#  '20.5k',
#  '20.4k',
#  '20.3k',
#  '19.4k',
#  '18.5k',
#  '18.4k',
#  '17.8k']

# %%
list_of_tuples = list(zip(name, rating, reviews))
# Out:
# [('TCS', '3.8', '71.9k'),
#  ('Accenture', '4.0', '45.5k'),
#  ('Cognizant', '3.9', '41k'),
#  ('Wipro', '3.8', '36.4k'),
#  ('HDFC Bank', '3.9', '33.3k'),
#  ('ICICI Bank', '4.0', '33k'),
#  ('Infosys', '3.8', '31.2k'),
#  ('Capgemini', '3.8', '29.1k'),
#  ('HCLTech', '3.6', '27.9k'),
#  ('Tech Mahindra', '3.7', '27.1k'),
#  ('Genpact', '3.9', '25.7k'),
#  ('Axis Bank', '3.8', '21.7k'),
#  ('Concentrix Corporation', '3.9', '21.4k'),
#  ('Teleperformance', '3.5', '20.5k'),
#  ('Amazon', '4.1', '20.4k'),
#  ('Reliance Jio', '4.0', '20.3k'),
#  ('IBM', '4.1', '19.4k'),
#  ('Larsen & Toubro Limited', '4.0', '18.5k'),
#  ('Reliance Retail', '3.9', '18.4k'),
#  ('HDB Financial Services', '4.0', '17.8k')]

# %%
df7 = pd.DataFrame(list_of_tuples,
                  columns=['Name', 'rating', 'reviews'])
df7
# Out:
#                        Name rating reviews
# 0                       TCS    3.8   71.9k
# 1                 Accenture    4.0   45.5k
# 2                 Cognizant    3.9     41k
# 3                     Wipro    3.8   36.4k
# 4                 HDFC Bank    3.9   33.3k
# 5                ICICI Bank    4.0     33k
# 6                   Infosys    3.8   31.2k
# 7                 Capgemini    3.8   29.1k
# 8                   HCLTech    3.6   27.9k
# 9             Tech Mahindra    3.7   27.1k
# 10                  Genpact    3.9   25.7k
# 11                Axis Bank    3.8   21.7k
# 12   Concentrix Corporation    3.9   21.4k
# 13          Teleperformance    3.5   20.5k
# 14                   Amazon    4.1   20.4k
# 15             Reliance Jio    4.0   20.3k
# 16                      IBM    4.1   19.4k
# 17  Larsen & Toubro Limited    4.0   18.5k
# 18          Reliance Retail    3.9   18.4k
# 19   HDB Financial Services    4.0   17.8k
